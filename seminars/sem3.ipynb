# %%
# !pip install yfinance

# %%
import yfinance as yf

stock_name = 'AAPL' # Apple ticker
stocks = yf.Ticker(stock_name)

# get historical market data over 10 years
ts = stocks.history(period="10y")

ts
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 2011-01-13   10.634018   10.679615   10.593658   10.650039   296780400
# 2011-01-14   10.656512   10.736307   10.611839   10.736307   308840000
# 2011-01-18   10.152169   10.621696   10.043721   10.495072  1880998000
# 2011-01-19   10.732300   10.740002   10.378921   10.439307  1135612800
# 2011-01-20   10.365058   10.422671   10.170654   10.249525   764789200
# ...                ...         ...         ...         ...         ...
# 2021-01-06  127.720001  131.050003  126.379997  126.599998   155088000
# 2021-01-07  128.360001  131.630005  127.860001  130.919998   109578200
# 2021-01-08  132.429993  132.630005  130.229996  132.050003   105158200
# 2021-01-11  129.190002  130.169998  128.500000  128.979996   100620900
# 2021-01-12  128.500000  129.690002  126.860001  128.800003    91722800
#
#             Dividends  Stock Splits
# Date
# 2011-01-13        0.0           0.0
# ...

# %% [markdown]
# # Train test split

# %%
ts_train, ts_test = ts['Close'][:2018], ts['Close'][2018:]

# %% [markdown]
# # Visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(17,10))

plt.title(stock_name)
plt.ylabel('Price ($)')
plt.plot(ts_train, label='train')
plt.plot(ts_test, label='test')
plt.legend()

# %% [markdown]
# # Data normalization

# %%
# Don't do that!

### Normalize data and format to the shape (seq_length, window_size, n_features(=1))

### Your code here
???

# %% [markdown]
# # Creating a model

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# Define your RNN model

### Your code here

???

### Fit your model

???
# Out:
# Epoch 1/100
# 63/63 [==============================] - 3s 47ms/step - loss: 0.0164 - val_loss: 0.2688
# Epoch 2/100
# 63/63 [==============================] - 1s 18ms/step - loss: 0.0030 - val_loss: 0.1611
# Epoch 3/100
# 63/63 [==============================] - 1s 18ms/step - loss: 0.0025 - val_loss: 0.2565
# Epoch 4/100
# 63/63 [==============================] - 1s 18ms/step - loss: 0.0030 - val_loss: 0.2431
# Epoch 5/100
# 63/63 [==============================] - 1s 17ms/step - loss: 0.0025 - val_loss: 0.2209
# Epoch 6/100
# 63/63 [==============================] - 1s 18ms/step - loss: 0.0026 - val_loss: 0.1509
# Epoch 7/100
# 63/63 [==============================] - 1s 18ms/step - loss: 0.0029 - val_loss: 0.1525
# Epoch 8/100
# 63/63 [==============================] - 1s 17ms/step - loss: 0.0028 - val_loss: 0.2191
# Epoch 9/100
# 63/63 [==============================] - 1s 17ms/step - loss: 0.0023 - val_loss: 0.2309
# Epoch 10/100
# ...

# %%
# Visualize the results

### Your code here

???
